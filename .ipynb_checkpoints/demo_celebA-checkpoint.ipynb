# %%
import torch
from torch.utils.data import DataLoader 
import torchvision 
from matplotlib import pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
from helpers import * 
from train import *
from utils import UNet
from plot import * 
from sampling import *

# %% [markdown]
# ## Load data

# %%
pip install deeplake
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://build-nexus.prod.crto.in/repository/moab.pypi/simple
# Collecting deeplake
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/deeplake/3.1.9/deeplake-3.1.9.tar.gz (414 kB)
#      |################################| 414 kB 3.0 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/i.sebag/.local/lib/python3.6/site-packages (from deeplake) (1.19.5)
# Requirement already satisfied: pillow in /home/i.sebag/.local/lib/python3.6/site-packages (from deeplake) (8.4.0)
# Collecting boto3
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/boto3/1.23.10/boto3-1.23.10-py3-none-any.whl (132 kB)
#      |################################| 132 kB 73.4 MB/s
# Collecting click
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/click/8.0.4/click-8.0.4-py3-none-any.whl (97 kB)
#      |################################| 97 kB 28.0 MB/s
# Collecting pathos
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/pathos/0.2.8/pathos-0.2.8-py2.py3-none-any.whl (81 kB)
#      |################################| 81 kB 27.8 MB/s
# Collecting humbug>=0.2.6
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/humbug/0.2.7/humbug-0.2.7-py3-none-any.whl (11 kB)
# Requirement already satisfied: tqdm in /home/i.sebag/.local/lib/python3.6/site-packages (from deeplake) (4.64.1)
# Collecting numcodecs
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/numcodecs/0.9.1/numcodecs-0.9.1-cp36-cp36m-manylinux2010_x86_64.whl (6.2 MB)
#      |################################| 6.2 MB 120.7 MB/s
# Collecting pyjwt
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/pyjwt/2.4.0/PyJWT-2.4.0-py3-none-any.whl (18 kB)
# Collecting hub>=2.8.7
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/hub/3.0.1/hub-3.0.1-py3-none-any.whl (1.4 kB)
# Requirement already satisfied: dataclasses in /home/i.sebag/.local/lib/python3.6/site-packages (from humbug>=0.2.6->deeplake) (0.8)
# Requirement already satisfied: requests in /home/i.sebag/.local/lib/python3.6/site-packages (from humbug>=0.2.6->deeplake) (2.27.1)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/jmespath/0.10.0/jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting botocore<1.27.0,>=1.26.10
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/botocore/1.26.10/botocore-1.26.10-py3-none-any.whl (8.8 MB)
#      |################################| 8.8 MB 129.4 MB/s
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/s3transfer/0.5.2/s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      |################################| 79 kB 43.7 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.6/site-packages (from click->deeplake) (4.8.3)
# Collecting pox>=0.3.0
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/pox/0.3.0/pox-0.3.0-py2.py3-none-any.whl (30 kB)
# Collecting dill>=0.3.4
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/dill/0.3.4/dill-0.3.4-py2.py3-none-any.whl (86 kB)
#      |################################| 86 kB 26.5 MB/s
# Collecting multiprocess>=0.70.12
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/multiprocess/0.70.12.2/multiprocess-0.70.12.2-py36-none-any.whl (106 kB)
#      |################################| 106 kB 141.3 MB/s
# Collecting ppft>=1.6.6.4
#   Downloading https://build-nexus.prod.crto.in/repository/moab.pypi/packages/ppft/1.6.6.4/ppft-1.6.6.4-py3-none-any.whl (65 kB)
#      |################################| 65 kB 17.4 MB/s
# Requirement already satisfied: importlib-resources in /home/i.sebag/.local/lib/python3.6/site-packages (from tqdm->deeplake) (5.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/i.sebag/.local/lib/python3.6/site-packages (from botocore<1.27.0,>=1.26.10->boto3->deeplake) (1.26.13)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/i.sebag/.local/lib/python3.6/site-packages (from botocore<1.27.0,>=1.26.10->boto3->deeplake) (2.8.2)
# Requirement already satisfied: six>=1.7.3 in /usr/local/lib/python3.6/site-packages (from ppft>=1.6.6.4->pathos->deeplake) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/site-packages (from importlib-metadata->click->deeplake) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.6/site-packages (from importlib-metadata->click->deeplake) (4.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/i.sebag/.local/lib/python3.6/site-packages (from requests->humbug>=0.2.6->deeplake) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/i.sebag/.local/lib/python3.6/site-packages (from requests->humbug>=0.2.6->deeplake) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/i.sebag/.local/lib/python3.6/site-packages (from requests->humbug>=0.2.6->deeplake) (2022.12.7)
# Building wheels for collected packages: deeplake
#   Building wheel for deeplake (setup.py) ... done
#   Created wheel for deeplake: filename=deeplake-3.1.9-py3-none-any.whl size=505170 sha256=c652ee66c69d5e4a64383e8a568da81f16c927dd6e1b6dee1c0eb22c1381d333
#   Stored in directory: /home/i.sebag/.cache/pip/wheels/dd/be/e4/636592989c26943777909f36fc5814a1f2c08d79d8936f7ec4
# Successfully built deeplake
# Installing collected packages: jmespath, dill, botocore, s3transfer, ppft, pox, multiprocess, pyjwt, pathos, numcodecs, humbug, hub, click, boto3, deeplake
# Successfully installed boto3-1.23.10 botocore-1.26.10 click-8.0.4 deeplake-3.1.9 dill-0.3.4 hub-3.0.1 humbug-0.2.7 jmespath-0.10.0 multiprocess-0.70.12.2 numcodecs-0.9.1 pathos-0.2.8 pox-0.3.0 ppft-1.6.6.4 pyjwt-2.4.0 s3transfer-0.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import deeplake

# %%
ds = deeplake.load("hub://activeloop/celeb-a-train")
# Out:
# hub://activeloop/celeb-a-train loaded successfully.
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/celeb-a-train

# %%
import deeplake
dataset = deeplake.load("hub://activeloop/celeb-a-val")
# Out:
# hub://activeloop/celeb-a-val loaded successfully.
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/celeb-a-val

# %%
#dataset = torchvision.datasets.CelebA(root="celeba/",split='train', download=True)

# %%
#pip list

# %%
train_dataloader = DataLoader(dataset, batch_size=8, shuffle=True)

# %%
x, y = next(iter(train_dataloader))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-115d5b5dbf77> in <module>
# ----> 1 x, y = next(iter(train_dataloader))
#
# ~/.local/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/.local/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# ~/.local/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
# ---> 52         return self.collate_fn(data)
#
# ~/.local/lib/python3.6/site-packages/torch/utils/data/_utils/collate.py in default_collate(batch)
#      84         return [default_collate(samples) for samples in transposed]
#      85
# ---> 86     raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'deeplake.core.dataset.deeplake_cloud_dataset.DeepLakeCloudDataset'>

# %% [markdown]
# ## Observe the corrupted data

# %%
plot_data(x, data=True, corrupted =True, predicted=False)

# %% [markdown]
# ## Training

# %%
losses = train(dataset, epochs=20, learning_rate=1e-3, batch_size=128)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c2c847ba0af0> in <module>
# ----> 1 losses = train(dataset, epochs=20, learning_rate=1e-3, batch_size=128)
#
# NameError: name 'dataset' is not defined

# %%
#We can try to see what the model predictions look like by grabbing a batch of data
#corrupting it my different amounts 
#and then seeing the models predictions:

# Fetch some data
x, y = next(iter(train_dataloader))
x = x[:8] # Only using the first 8 for easy plotting

#Plot
plot_data(x, data=True, corrupted =True, predicted=True)

# %% [markdown]
# ## Sampling

# %%
steps=50
step_history, pred_output_history = sampling(steps)

# %%
fig, axs = plt.subplots(steps, 2, figsize=(20, 50), sharex=True)
axs[0,0].set_title('x (model input)')
axs[0,1].set_title('model prediction')
for i in range(steps):
    axs[i, 0].imshow(torchvision.utils.make_grid(step_history[i])[0].clip(0, 1), cmap='Greys')
    axs[i, 1].imshow(torchvision.utils.make_grid(pred_output_history[i])[0].clip(0, 1), cmap='Greys')
